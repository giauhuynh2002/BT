# %% [markdown]
# <a href="https://colab.research.google.com/github/giauhuynh2002/HuynhPhatGiau-20104026/blob/main/nhan_dien_hoa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Khai báo các thư viện cần sử dụng
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import SGD, RMSprop
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.utils import validation 
from sklearn import preprocessing
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
#Kết nối với google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Tạo ra class ImageDataGenerator để chỉnh sửa ảnh 
train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/BT AI/Hoa/train', target_size=(224,224), batch_size=32, class_mode='categorical')
# Out:
# Found 88 images belonging to 3 classes.

# %%
# Tạo bộ dữ liệu test
test_set = train_datagen.flow_from_directory('/content/drive/MyDrive/BT AI/Hoa/test', target_size=(224,224), batch_size=32, class_mode='categorical')
# Out:
# Found 15 images belonging to 3 classes.

# %%
# Các nhãn có trong bộ dữ liệu training
training_set.class_indices
# Out:
# {'rose': 0, 'sen': 1, 'tulip': 2}

# %%
# Các nhãn có trong bộ dữ liệu test
test_set.class_indices
# Out:
# {'rose': 0, 'sen': 1, 'tulip': 2}

# %%
x_train = np.concatenate([training_set.next()[0] for i in range(training_set.__len__())])
y_train = np.concatenate([training_set.next()[1] for i in range(training_set.__len__())])
print(x_train.shape)
print(y_train.shape)
# Out:
# (88, 224, 224, 3)
# (88, 3)

# %%
x_test = np.concatenate([test_set.next()[0] for i in range(test_set.__len__())])
y_test = np.concatenate([test_set.next()[1] for i in range(test_set.__len__())])
print(x_test.shape)
print(y_test.shape)
# Out:
# (15, 224, 224, 3)
# (15, 3)

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(2048, activation = "relu", input_shape = (224*224*3,)))
model.add(layers.Dense(2048, activation= "relu"))
model.add(layers.Dense(3, activation= "softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2048)              308283392
#
#  dense_1 (Dense)             (None, 2048)              4196352
#
#  dense_2 (Dense)             (None, 3)                 6147
#
# =================================================================
# Total params: 312,485,891
# Trainable params: 312,485,891
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train = x_train.reshape((88,224*224*3))
x_test = x_test.reshape((15,224*224*3))
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
'''from keras.utils import np_utils
y_train = np_utils.to_categorical(y_train,3)
y_test = np_utils.to_categorical(y_test,3)'''
# Out:
# 'from keras.utils import np_utils\ny_train = np_utils.to_categorical(y_train,3)\ny_test = np_utils.to_categorical(y_test,3)'

# %%
x_train.shape
# Out:
# (88, 150528)

# %%
y_train.shape
# Out:
# (88, 3)

# %%
model.compile(optimizer="rmsprop", loss = "categorical_crossentropy", metrics=["accuracy"])
model.fit(x_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 15s 3s/step - loss: 7.4603 - accuracy: 0.2841
# Epoch 2/100
# 3/3 [==============================] - 9s 3s/step - loss: 5.9771 - accuracy: 0.2727
# Epoch 3/100
# 3/3 [==============================] - 10s 3s/step - loss: 1.2399 - accuracy: 0.3295
# Epoch 4/100
# 3/3 [==============================] - 11s 3s/step - loss: 1.0847 - accuracy: 0.3864
# Epoch 5/100
# 3/3 [==============================] - 9s 3s/step - loss: 1.2204 - accuracy: 0.4318
# Epoch 6/100
# 3/3 [==============================] - 9s 3s/step - loss: 1.0765 - accuracy: 0.5455
# Epoch 7/100
# 3/3 [==============================] - 9s 3s/step - loss: 1.0293 - accuracy: 0.4432
# Epoch 8/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.9975 - accuracy: 0.4432
# Epoch 9/100
# 3/3 [==============================] - 13s 4s/step - loss: 1.1512 - accuracy: 0.3523
# Epoch 10/100
# 3/3 [==============================] - 9s 3s/step - loss: 1.0536 - accuracy: 0.5000
# Epoch 11/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.9871 - accuracy: 0.5227
# Epoch 12/100
# 3/3 [==============================] - 8s 3s/step - loss: 1.0762 - accuracy: 0.4432
# Epoch 13/100
# 3/3 [==============================] - 9s 3s/step - loss: 1.5049 - accuracy: 0.3409
# Epoch 14/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.9470 - accuracy: 0.6250
# Epoch 15/100
# 3/3 [==============================] - 9s 3s/step - loss: 1.1808 - accuracy: 0.3523
# Epoch 16/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.9675 - accuracy: 0.6136
# Epoch 17/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.8418 - accuracy: 0.6023
# Epoch 18/100
# 3/3 [==============================] - 10s 3s/step - loss: 1.1858 - accuracy: 0.4659
# Epoch 19/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.8852 - accuracy: 0.6477
# Epoch 20/100
# 3/3 [==============================] - 12s 5s/step - loss: 0.9196 - accuracy: 0.5455
# Epoch 21/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.8213 - accuracy: 0.6023
# Epoch 22/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.9173 - accuracy: 0.5909
# Epoch 23/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.8932 - accuracy: 0.5568
# Epoch 24/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.6385 - accuracy: 0.8182
# Epoch 25/100
# 3/3 [==============================] - 9s 3s/step - loss: 1.2878 - accuracy: 0.4659
# Epoch 26/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.6621 - accuracy: 0.7386
# Epoch 27/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.8621 - accuracy: 0.6705
# Epoch 28/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.9564 - accuracy: 0.5455
# Epoch 29/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.5943 - accuracy: 0.7841
# Epoch 30/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.9763 - accuracy: 0.6250
# Epoch 31/100
# 3/3 [==============================] - 9s 3s/step - loss: 1.0153 - accuracy: 0.5114
# Epoch 32/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.5268 - accuracy: 0.8068
# Epoch 33/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.4388 - accuracy: 0.8523
# Epoch 34/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.5926 - accuracy: 0.7159
# Epoch 35/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.4266 - accuracy: 0.8182
# Epoch 36/100
# 3/3 [==============================] - 8s 3s/step - loss: 1.3482 - accuracy: 0.5568
# Epoch 37/100
# 3/3 [==============================] - 10s 4s/step - loss: 0.4702 - accuracy: 0.8523
# Epoch 38/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.3322 - accuracy: 0.8864
# Epoch 39/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.4708 - accuracy: 0.8409
# Epoch 40/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.7979 - accuracy: 0.6818
# Epoch 41/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.4395 - accuracy: 0.8523
# Epoch 42/100
# 3/3 [==============================] - 10s 3s/step - loss: 1.0703 - accuracy: 0.5909
# Epoch 43/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.4383 - accuracy: 0.8409
# Epoch 44/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.5174 - accuracy: 0.8295
# Epoch 45/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.4046 - accuracy: 0.7955
# Epoch 46/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.2533 - accuracy: 0.8750
# Epoch 47/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.4182 - accuracy: 0.8295
# Epoch 48/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.7314 - accuracy: 0.6591
# Epoch 49/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.2643 - accuracy: 0.9205
# Epoch 50/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.1450 - accuracy: 0.9886
# Epoch 51/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.4384 - accuracy: 0.7841
# Epoch 52/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.5563 - accuracy: 0.7955
# Epoch 53/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.1936 - accuracy: 0.9432
# Epoch 54/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.1004 - accuracy: 1.0000
# Epoch 55/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0916 - accuracy: 0.9886
# Epoch 56/100
# 3/3 [==============================] - 10s 3s/step - loss: 1.6715 - accuracy: 0.6023
# Epoch 57/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.5383 - accuracy: 0.7727
# Epoch 58/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.1831 - accuracy: 0.9659
# Epoch 59/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.1293 - accuracy: 0.9545
# Epoch 60/100
# 3/3 [==============================] - 10s 4s/step - loss: 0.1130 - accuracy: 0.9773
# Epoch 61/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.2385 - accuracy: 0.9205
# Epoch 62/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.4172 - accuracy: 0.7955
# Epoch 63/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0919 - accuracy: 0.9886
# Epoch 64/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.1358 - accuracy: 0.9545
# Epoch 65/100
# 3/3 [==============================] - 11s 4s/step - loss: 0.0714 - accuracy: 0.9773
# Epoch 66/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.5514 - accuracy: 0.8068
# Epoch 67/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.2874 - accuracy: 0.8750
# Epoch 68/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0744 - accuracy: 0.9773
# Epoch 69/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.1633 - accuracy: 0.9432
# Epoch 70/100
# 3/3 [==============================] - 8s 3s/step - loss: 2.3703 - accuracy: 0.5455
# Epoch 71/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.1843 - accuracy: 0.9773
# Epoch 72/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0988 - accuracy: 0.9886
# Epoch 73/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.1370 - accuracy: 0.9432
# Epoch 74/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0517 - accuracy: 0.9886
# Epoch 75/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.2178 - accuracy: 0.9205
# Epoch 76/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0453 - accuracy: 1.0000
# Epoch 77/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0352 - accuracy: 0.9886
# Epoch 78/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 79/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.0315 - accuracy: 0.9886
# Epoch 80/100
# 3/3 [==============================] - 8s 3s/step - loss: 1.8561 - accuracy: 0.6591
# Epoch 81/100
# 3/3 [==============================] - 9s 3s/step - loss: 3.6140 - accuracy: 0.5455
# Epoch 82/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.1298 - accuracy: 1.0000
# Epoch 83/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0858 - accuracy: 0.9886
# Epoch 84/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.0594 - accuracy: 1.0000
# Epoch 85/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0592 - accuracy: 0.9773
# Epoch 86/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.0625 - accuracy: 0.9773
# Epoch 87/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0269 - accuracy: 1.0000
# Epoch 88/100
# 3/3 [==============================] - 17s 5s/step - loss: 0.1514 - accuracy: 0.9545
# Epoch 89/100
# 3/3 [==============================] - 10s 3s/step - loss: 2.0972 - accuracy: 0.6477
# Epoch 90/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.1010 - accuracy: 0.9886
# Epoch 91/100
# 3/3 [==============================] - 10s 4s/step - loss: 0.0712 - accuracy: 0.9773
# Epoch 92/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0728 - accuracy: 0.9659
# Epoch 93/100
# 3/3 [==============================] - 10s 3s/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 94/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0322 - accuracy: 1.0000
# Epoch 95/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 96/100
# 3/3 [==============================] - 9s 3s/step - loss: 0.0905 - accuracy: 0.9545
# Epoch 97/100
# 3/3 [==============================] - 8s 2s/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 98/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.7493 - accuracy: 0.7955
# Epoch 99/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.6886 - accuracy: 0.7727
# Epoch 100/100
# 3/3 [==============================] - 8s 3s/step - loss: 0.0641 - accuracy: 1.0000

# %%
# Đánh giá độ chính xác của mô hình 
Score=model.evaluate(x_train,y_train,verbose=0)
print('Train Loss', Score[0])
print('Train Accuracy', Score[1])
# Out:
# Train Loss 0.038072094321250916
# Train Accuracy 1.0

# %%
# Lưu lại
model.save("Nhan_dien_hoa.h5")

# %%
# Tải mô hình 
model_ANN=load_model('Nhan_dien_hoa.h5')

# %%
class_names = ["rose", "sen", "tulip"]

# %%
from tensorflow.keras.utils import load_img
from keras.utils.image_utils import img_to_array
import numpy as np

url = "/content/drive/MyDrive/BT AI/Hoa/test/sen/sen (21).jpg"
img = load_img(url, target_size=(224,224,3))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1, 224, 224, 3)
img = img.astype("float32")
img = img/255
img = img.reshape(-1, 224*224*3)

prediction = model.predict(img)
np.argmax(prediction, axis=1)
index = -1
max_value = -1

for i in range(0, len(prediction[0])):
  if max_value < prediction[0][i]:
    max_value = prediction[0][i]
    index = i
print(prediction)
print("Kết quả: ", class_names[index])
print("Độ chính xác: ", max_value)
# Out:
# 1/1 [==============================] - 0s 154ms/step
# [[0. 1. 0.]]
# Kết quả:  sen
# Độ chính xác:  1.0
